# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv("/IRIS.csv")
display(df.head())
df.sample(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
#      sepal_length  sepal_width  petal_length  petal_width          species
# 42            4.4          3.2           1.3          0.2      Iris-setosa
# 140           6.7          3.1           5.6          2.4   Iris-virginica
# 85            6.0          3.4           4.5          1.6  Iris-versicolor
# 11            4.8          3.4           1.6          0.2      Iris-setosa
# 79            5.7          2.6           3.5          1.0  Iris-versicolor
# 137           6.4          3.1           5.5          1.8   Iris-virginica
# ...

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("demonllord/indian-smartphones-under-20000specs-prices")

print("Path to dataset files:", path)
# Out:
# ...
# Path to dataset files: /root/.cache/kagglehub/datasets/demonllord/indian-smartphones-under-20000specs-prices/versions/1

# %%
df=pd.read_csv("/kaggle/input/indian-smartphones-under-20000specs-prices/indian-smartphones-under-20000/data/indian_smartphones_under_20000_raw.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                                         Model Name    Price  \
# 0           0                vivo T4x 5G (Pronto Purple, 256 GB)  18499.0
# 1           1    MOTOROLA G96 5G (Pantone Ashleigh Blue, 256 GB)  18999.0
# 2           2                vivo T4x 5G (Pronto Purple, 128 GB)  16499.0
# 3           3  MOTOROLA G96 5G (Pantone Greener Pastures, 256...  18999.0
# 4           4                 realme P4x 5G (Lake Green, 256 GB)  17499.0
#
#   Percentage Discount   Ratings  Reviews              RAM & ROM  \
# 0             11% off  151361.0   7146.0  8 GB RAM | 256 GB ROM
# 1             17% off   81989.0   4125.0  8 GB RAM | 256 GB ROM
# 2             15% off  151361.0   7146.0  8 GB RAM | 128 GB ROM
# 3             17% off   81989.0   4125.0  8 GB RAM | 256 GB ROM
# 4             16% off    1211.0    125.0  8 GB RAM | 256 GB ROM
#
#                             Display Size                          Camera  \
# ...

# %%
import kagglehub
path = kagglehub.dataset_download("demonllord/indian-smartphones-under-20000specs-prices")
print(path)
# Out:
# Using Colab cache for faster access to the 'indian-smartphones-under-20000specs-prices' dataset.
# /kaggle/input/indian-smartphones-under-20000specs-prices

# %%
data=pd.read_csv("/kaggle/input/indian-smartphones-under-20000specs-prices/indian-smartphones-under-20000/data/indian_smartphones_under_20000_raw.csv")

# %%
data
# Out:
#        Unnamed: 0                                         Model Name    Price  \
# 0               0                vivo T4x 5G (Pronto Purple, 256 GB)  18499.0
# 1               1    MOTOROLA G96 5G (Pantone Ashleigh Blue, 256 GB)  18999.0
# 2               2                vivo T4x 5G (Pronto Purple, 128 GB)  16499.0
# 3               3  MOTOROLA G96 5G (Pantone Greener Pastures, 256...  18999.0
# 4               4                 realme P4x 5G (Lake Green, 256 GB)  17499.0
# ...           ...                                                ...      ...
# 11971       11971                   OPPO A6x 5G (Olive Green, 64 GB)  12499.0
# 11972       11972                  OPPO A6x 5G (Olive Green, 128 GB)  13499.0
# 11973       11973  realme C63 5G Charger in the Box (Forest Green...  10999.0
# 11974       11974           vivo Y19s 5G (Titanium Silver, 128.0 GB)  14499.0
# 11975       11975                  realme C73 5G (Onyx Black, 64 GB)  11999.0
#
# ...
